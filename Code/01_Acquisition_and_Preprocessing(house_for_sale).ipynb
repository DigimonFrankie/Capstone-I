# %% [markdown]
# ## Coded by
# - Frank Zhao
# - Gustavo Ferreira
# - Yan Li

# %% [markdown]
# ## Data aquiring date: 10/16/2020

# %% [markdown]
# # Import modules

# %%
import json
from pprint import pprint
import glob
from datetime import datetime
import requests
import pandas as pd

# %% [markdown]
# # Self-define functions

# %%
## function for realtor api requests

def realtor_api_request(sort = "relevance", city = "Philadelphia", limit = "200", offset = "0", state_code = "PA"):
    url = "https://realtor.p.rapidapi.com/properties/v2/list-for-sale"

    querystring = {
        "sort": sort,
        "city": city,
        "limit": limit,
        "offset": offset,
        "state_code": state_code
    }

    headers = {
        'x-rapidapi-host': "realtor.p.rapidapi.com",
        'x-rapidapi-key': "e2aef74c96msh10b708b155c5b67p1e6d19jsn4cb3a156a37d"
        }

    response = requests.request("GET", url, headers=headers, params=querystring)
    
    return response.json()

# %%
## convert response to pandas df

def process_response(response_json):
    '''
    This function is to convert each request result to a dataframe.
    
    1. create an empty list
    2. loop for each response and get details from key 'properties' 
    3. convert details to df
    4. append single df to list
    5. concat the list to one df
    
    '''
    
    # empty list
    convert_list=[]
#     if response_json['properties']: return pd.DataFrame([])
    # loop through each 'properties'
    for col in response_json['properties']:
        
        # convert details to dataframe
        single_df = pd.DataFrame.from_dict(col, orient='index').T
        
        # append to list
        convert_list.append(single_df)
        
    # concat to a whole df, null for missing vals
    return pd.concat(convert_list, axis = 0, ignore_index=True, sort=False)

# %% [markdown]
# # Get data

# %%
## run for each offset
'''
There are 200 instances in each request. Restricted by Rapidapi
'''
def response_to_df(sort = "relevance", city = "Philadelphia", limit = "200", offset = "0", state_code = "PA"):
    property_for_sale = realtor_api_request(sort = sort, city = city, limit = limit, offset = offset, state_code = state_code)
    df_properties_for_sale_raw = process_response(response_json = property_for_sale)
    pd.set_option('display.max_columns', None)
    return df_properties_for_sale_raw

# %% [markdown]
# # Export response to csv file

# %%
## export each response to csv file
'''
Since each request could get 200 instances, after the each request, we increase the offset 200.
So on the second run, we can get data from 201 - 400, theoratically.
However, the system will keep updating the data so we may either get the data overlapped or miss some data.
We will deal with duplicated data later.

Currently, the loop will crash when the instances in the last run is less than 200. 
'''

start = datetime.now() ## to see how long will it finish the run
i=1
for offset in range(0, 9562, 200):
    response_to_df(offset = offset).to_csv(f'test{i}.csv',encoding='utf-8', index=False)
    if i % 10 == 0:
        print(f'The {i}th Time')
    i += 1    
end = datetime.now() -start

print(f'Total time is: {end}')
# Out:
# The 10th Time
# The 20th Time
# The 30th Time
# The 40th Time
# Total time is: 0:02:54.604970

# %% [markdown]
# # Data preprocessing

# %%
## import all csv to one df

path = r'E:\Projects\Drexel\DSCI 591 Capstone I\Projects\csv'
all_files = glob.glob(path + "/*.csv")

## empty list
file_list = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    file_list.append(df)
    
combined_df = pd.concat(file_list, axis = 0, ignore_index=True)

combined_df
# Out:
#       property_id    listing_id  \
# 0     M4046594895  2.922386e+09
# 1     M3939384476  2.918257e+09
# 2     M4036371277  2.922385e+09
# 3     M3553029343  2.922384e+09
# 4     M3649199107  2.922384e+09
# ...           ...           ...
# 9757  M3400474681  2.869904e+09
# 9758  M3654238233  2.890369e+09
# 9759  M9041602444  2.704677e+09
# 9760  M3276555576  2.915162e+09
# 9761  M9041954204  2.916159e+09
#
#                                             rdc_web_url      prop_type  \
# 0     https://www.realtor.com/realestateandhomes-det...          condo
# 1     https://www.realtor.com/realestateandhomes-det...          condo
# 2     https://www.realtor.com/realestateandhomes-det...          condo
# 3     https://www.realtor.com/realestateandhomes-det...  single_family
# 4     https://www.realtor.com/realestateandhomes-det...          condo
# ...                                                 ...            ...
# 9757  https://www.realtor.com/realestateandhomes-det...          condo
# 9758  https://www.realtor.com/realestateandhomes-det...          condo
# 9759  https://www.realtor.com/realestateandhomes-det...          condo
# 9760  https://www.realtor.com/realestateandhomes-det...          condo
# 9761  https://www.realtor.com/realestateandhomes-det...          condo
#
#        prop_sub_type                                            address  \
# 0     duplex_triplex  {'city': 'Philadelphia', 'line': '1516 N 62nd ...
# 1          townhomes  {'city': 'Philadelphia', 'line': '6102 Reedlan...
# 2          townhomes  {'city': 'Philadelphia', 'line': '5703 N 13th ...
# 3                NaN  {'city': 'Philadelphia', 'line': '1009 Rhawn S...
# 4          townhomes  {'city': 'Philadelphia', 'line': '3850 N Bouvi...
# ...              ...                                                ...
# 9757       townhomes  {'city': 'Philadelphia', 'line': '2077 Bridge ...
# 9758       townhomes  {'city': 'Philadelphia', 'line': '1452 N 57th ...
# 9759  duplex_triplex  {'city': 'Philadelphia', 'line': '7354 Ridge A...
# 9760          condos  {'city': 'Philadelphia', 'line': '1003 N Bodin...
# 9761       townhomes  {'city': 'Philadelphia', 'line': '1524 S 25th ...
#
#                                                branding prop_status   price  \
# 0     {'listing_office': {'list_item': {'name': 'Arc...    for_sale  249900
# 1     {'listing_office': {'list_item': {'name': 'Vih...    for_sale  116800
# 2     {'listing_office': {'list_item': {'name': 'Pre...    for_sale  215000
# 3     {'listing_office': {'list_item': {'name': 'Re/...    for_sale  394800
# 4     {'listing_office': {'list_item': {'name': 'Re/...    for_sale  130000
# ...                                                 ...         ...     ...
# 9757  {'listing_office': {'list_item': {'name': 'Re/...    for_sale   94900
# 9758  {'listing_office': {'list_item': {'name': 'Kel...    for_sale  149900
# 9759  {'listing_office': {'list_item': {'name': 'BHH...    for_sale  432990
# 9760  {'listing_office': {'list_item': {'name': 'Kel...    for_sale  405000
# 9761  {'listing_office': {'list_item': {'name': 'Hom...    for_sale  450000
#
#       baths_full  ...  rank  \
# 0            3.0  ...     1
# 1            1.0  ...     2
# 2            1.0  ...     3
# 3            1.0  ...     4
# 4            1.0  ...     5
# ...          ...  ...   ...
# 9757         1.0  ...    33
# 9758         1.0  ...    34
# 9759         3.0  ...    35
# 9760         2.0  ...    36
# 9761         3.0  ...    37
#
#                                           list_tracking  \
# 0     type|property|data|prop_id|4046594895|list_id|...
# 1     type|property|data|prop_id|3939384476|list_id|...
# 2     type|property|data|prop_id|4036371277|list_id|...
# 3     type|property|data|prop_id|3553029343|list_id|...
# 4     type|property|data|prop_id|3649199107|list_id|...
# ...                                                 ...
# 9757  type|property|data|prop_id|3400474681|list_id|...
# 9758  type|property|data|prop_id|3654238233|list_id|...
# 9759  type|property|data|prop_id|9041602444|list_id|...
# 9760  type|property|data|prop_id|3276555576|list_id|...
# 9761  type|property|data|prop_id|9041954204|list_id|...
#
#                               lot_size  \
# 0      {'size': 1842, 'units': 'sqft'}
# 1       {'size': 992, 'units': 'sqft'}
# 2      {'size': 1501, 'units': 'sqft'}
# 3     {'size': 15913, 'units': 'sqft'}
# 4      {'size': 1240, 'units': 'sqft'}
# ...                                ...
# 9757   {'size': 1064, 'units': 'sqft'}
# 9758   {'size': 1231, 'units': 'sqft'}
# 9759                               NaN
# 9760                               NaN
# 9761   {'size': 1200, 'units': 'sqft'}
#
#                                                     mls baths_half  \
# 0     {'name': 'BrightMLS', 'id': 'PAPH944934', 'pla...        NaN
# 1     {'name': 'BrightMLS', 'id': 'PAPH911464', 'pla...        NaN
# 2     {'name': 'BrightMLS', 'id': 'PAPH945010', 'pla...        1.0
# 3     {'name': 'BrightMLS', 'id': 'PAPH943096', 'pla...        1.0
# 4     {'name': 'BrightMLS', 'id': 'PAPH918016', 'pla...        1.0
# ...                                                 ...        ...
# 9757  {'name': 'BrightMLS', 'id': 'PAPH858856', 'pla...        NaN
# 9758  {'name': 'BrightMLS', 'id': 'PAPH858898', 'pla...        1.0
# 9759  {'name': 'BrightMLS', 'id': 'PAPH838626', 'pla...        1.0
# 9760  {'name': 'BrightMLS', 'id': 'PAPH888146', 'pla...        NaN
# 9761  {'name': 'BrightMLS', 'id': 'PAPH894490', 'pla...        NaN
#
#                                            virtual_tour open_houses plan_id  \
# 0                                                   NaN         NaN     NaN
# 1                                                   NaN         NaN     NaN
# 2                                                   NaN         NaN     NaN
# 3                                                   NaN         NaN     NaN
# 4     {'href': 'https://view.ricohtours.com/0701bde8...         NaN     NaN
# ...                                                 ...         ...     ...
# 9757                                                NaN         NaN     NaN
# 9758                                                NaN         NaN     NaN
# 9759                                                NaN         NaN     NaN
# 9760  {'href': 'https://my.matterport.com/show/?m=eR...         NaN     NaN
# 9761     {'href': 'https://www.grayspointephilly.com/'}         NaN     NaN
#
#       new_plan quick_to_sell_days
# 0          NaN                NaN
# 1          NaN                NaN
# 2          NaN                NaN
# 3          NaN                NaN
# 4          NaN                NaN
# ...        ...                ...
# 9757       NaN                NaN
# 9758       NaN                NaN
# 9759       NaN                NaN
# 9760       NaN                NaN
# 9761       NaN                NaN
#
# [9762 rows x 31 columns]

# %% [markdown]
# There are 9762 instances we achieved. However, there should be some duplicated instances.

# %%
## remove duplicated instances
raw_data = combined_df.drop_duplicates(subset=['property_id'])
raw_data
# Out:
#       property_id    listing_id  \
# 0     M4046594895  2.922386e+09
# 1     M3939384476  2.918257e+09
# 2     M4036371277  2.922385e+09
# 3     M3553029343  2.922384e+09
# 4     M3649199107  2.922384e+09
# ...           ...           ...
# 9757  M3400474681  2.869904e+09
# 9758  M3654238233  2.890369e+09
# 9759  M9041602444  2.704677e+09
# 9760  M3276555576  2.915162e+09
# 9761  M9041954204  2.916159e+09
#
#                                             rdc_web_url      prop_type  \
# 0     https://www.realtor.com/realestateandhomes-det...          condo
# 1     https://www.realtor.com/realestateandhomes-det...          condo
# 2     https://www.realtor.com/realestateandhomes-det...          condo
# 3     https://www.realtor.com/realestateandhomes-det...  single_family
# 4     https://www.realtor.com/realestateandhomes-det...          condo
# ...                                                 ...            ...
# 9757  https://www.realtor.com/realestateandhomes-det...          condo
# 9758  https://www.realtor.com/realestateandhomes-det...          condo
# 9759  https://www.realtor.com/realestateandhomes-det...          condo
# 9760  https://www.realtor.com/realestateandhomes-det...          condo
# 9761  https://www.realtor.com/realestateandhomes-det...          condo
#
#        prop_sub_type                                            address  \
# 0     duplex_triplex  {'city': 'Philadelphia', 'line': '1516 N 62nd ...
# 1          townhomes  {'city': 'Philadelphia', 'line': '6102 Reedlan...
# 2          townhomes  {'city': 'Philadelphia', 'line': '5703 N 13th ...
# 3                NaN  {'city': 'Philadelphia', 'line': '1009 Rhawn S...
# 4          townhomes  {'city': 'Philadelphia', 'line': '3850 N Bouvi...
# ...              ...                                                ...
# 9757       townhomes  {'city': 'Philadelphia', 'line': '2077 Bridge ...
# 9758       townhomes  {'city': 'Philadelphia', 'line': '1452 N 57th ...
# 9759  duplex_triplex  {'city': 'Philadelphia', 'line': '7354 Ridge A...
# 9760          condos  {'city': 'Philadelphia', 'line': '1003 N Bodin...
# 9761       townhomes  {'city': 'Philadelphia', 'line': '1524 S 25th ...
#
#                                                branding prop_status   price  \
# 0     {'listing_office': {'list_item': {'name': 'Arc...    for_sale  249900
# 1     {'listing_office': {'list_item': {'name': 'Vih...    for_sale  116800
# 2     {'listing_office': {'list_item': {'name': 'Pre...    for_sale  215000
# 3     {'listing_office': {'list_item': {'name': 'Re/...    for_sale  394800
# 4     {'listing_office': {'list_item': {'name': 'Re/...    for_sale  130000
# ...                                                 ...         ...     ...
# 9757  {'listing_office': {'list_item': {'name': 'Re/...    for_sale   94900
# 9758  {'listing_office': {'list_item': {'name': 'Kel...    for_sale  149900
# 9759  {'listing_office': {'list_item': {'name': 'BHH...    for_sale  432990
# 9760  {'listing_office': {'list_item': {'name': 'Kel...    for_sale  405000
# 9761  {'listing_office': {'list_item': {'name': 'Hom...    for_sale  450000
#
#       baths_full  ...  rank  \
# 0            3.0  ...     1
# 1            1.0  ...     2
# 2            1.0  ...     3
# 3            1.0  ...     4
# 4            1.0  ...     5
# ...          ...  ...   ...
# 9757         1.0  ...    33
# 9758         1.0  ...    34
# 9759         3.0  ...    35
# 9760         2.0  ...    36
# 9761         3.0  ...    37
#
#                                           list_tracking  \
# 0     type|property|data|prop_id|4046594895|list_id|...
# 1     type|property|data|prop_id|3939384476|list_id|...
# 2     type|property|data|prop_id|4036371277|list_id|...
# 3     type|property|data|prop_id|3553029343|list_id|...
# 4     type|property|data|prop_id|3649199107|list_id|...
# ...                                                 ...
# 9757  type|property|data|prop_id|3400474681|list_id|...
# 9758  type|property|data|prop_id|3654238233|list_id|...
# 9759  type|property|data|prop_id|9041602444|list_id|...
# 9760  type|property|data|prop_id|3276555576|list_id|...
# 9761  type|property|data|prop_id|9041954204|list_id|...
#
#                               lot_size  \
# 0      {'size': 1842, 'units': 'sqft'}
# 1       {'size': 992, 'units': 'sqft'}
# 2      {'size': 1501, 'units': 'sqft'}
# 3     {'size': 15913, 'units': 'sqft'}
# 4      {'size': 1240, 'units': 'sqft'}
# ...                                ...
# 9757   {'size': 1064, 'units': 'sqft'}
# 9758   {'size': 1231, 'units': 'sqft'}
# 9759                               NaN
# 9760                               NaN
# 9761   {'size': 1200, 'units': 'sqft'}
#
#                                                     mls baths_half  \
# 0     {'name': 'BrightMLS', 'id': 'PAPH944934', 'pla...        NaN
# 1     {'name': 'BrightMLS', 'id': 'PAPH911464', 'pla...        NaN
# 2     {'name': 'BrightMLS', 'id': 'PAPH945010', 'pla...        1.0
# 3     {'name': 'BrightMLS', 'id': 'PAPH943096', 'pla...        1.0
# 4     {'name': 'BrightMLS', 'id': 'PAPH918016', 'pla...        1.0
# ...                                                 ...        ...
# 9757  {'name': 'BrightMLS', 'id': 'PAPH858856', 'pla...        NaN
# 9758  {'name': 'BrightMLS', 'id': 'PAPH858898', 'pla...        1.0
# 9759  {'name': 'BrightMLS', 'id': 'PAPH838626', 'pla...        1.0
# 9760  {'name': 'BrightMLS', 'id': 'PAPH888146', 'pla...        NaN
# 9761  {'name': 'BrightMLS', 'id': 'PAPH894490', 'pla...        NaN
#
#                                            virtual_tour open_houses plan_id  \
# 0                                                   NaN         NaN     NaN
# 1                                                   NaN         NaN     NaN
# 2                                                   NaN         NaN     NaN
# 3                                                   NaN         NaN     NaN
# 4     {'href': 'https://view.ricohtours.com/0701bde8...         NaN     NaN
# ...                                                 ...         ...     ...
# 9757                                                NaN         NaN     NaN
# 9758                                                NaN         NaN     NaN
# 9759                                                NaN         NaN     NaN
# 9760  {'href': 'https://my.matterport.com/show/?m=eR...         NaN     NaN
# 9761     {'href': 'https://www.grayspointephilly.com/'}         NaN     NaN
#
#       new_plan quick_to_sell_days
# 0          NaN                NaN
# 1          NaN                NaN
# 2          NaN                NaN
# 3          NaN                NaN
# 4          NaN                NaN
# ...        ...                ...
# 9757       NaN                NaN
# 9758       NaN                NaN
# 9759       NaN                NaN
# 9760       NaN                NaN
# 9761       NaN                NaN
#
# [9562 rows x 31 columns]

# %%
## export to csv file
raw_data.to_csv('raw_data.csv', encoding='utf-8', index=False)

# %% [markdown]
# And now, we have all 9562 instances.

# %%
## Remove unuseful cols
processed_data = raw_data.drop(columns=[
    'rdc_web_url',
    'office',
    'thumbnail',
    'list_tracking',
    'open_houses',
    'plan_id',
    'new_plan',
    'quick_to_sell_days',
    'virtual_tour',
    'client_display_flags',
    'lead_forms',
    'listing_id',
    'mls'
    
])
processed_data
# Out:
#       property_id      prop_type   prop_sub_type  \
# 0     M4046594895          condo  duplex_triplex
# 1     M3939384476          condo       townhomes
# 2     M4036371277          condo       townhomes
# 3     M3553029343  single_family             NaN
# 4     M3649199107          condo       townhomes
# ...           ...            ...             ...
# 9757  M3400474681          condo       townhomes
# 9758  M3654238233          condo       townhomes
# 9759  M9041602444          condo  duplex_triplex
# 9760  M3276555576          condo          condos
# 9761  M9041954204          condo       townhomes
#
#                                                 address  \
# 0     {'city': 'Philadelphia', 'line': '1516 N 62nd ...
# 1     {'city': 'Philadelphia', 'line': '6102 Reedlan...
# 2     {'city': 'Philadelphia', 'line': '5703 N 13th ...
# 3     {'city': 'Philadelphia', 'line': '1009 Rhawn S...
# 4     {'city': 'Philadelphia', 'line': '3850 N Bouvi...
# ...                                                 ...
# 9757  {'city': 'Philadelphia', 'line': '2077 Bridge ...
# 9758  {'city': 'Philadelphia', 'line': '1452 N 57th ...
# 9759  {'city': 'Philadelphia', 'line': '7354 Ridge A...
# 9760  {'city': 'Philadelphia', 'line': '1003 N Bodin...
# 9761  {'city': 'Philadelphia', 'line': '1524 S 25th ...
#
#                                                branding prop_status   price  \
# 0     {'listing_office': {'list_item': {'name': 'Arc...    for_sale  249900
# 1     {'listing_office': {'list_item': {'name': 'Vih...    for_sale  116800
# 2     {'listing_office': {'list_item': {'name': 'Pre...    for_sale  215000
# 3     {'listing_office': {'list_item': {'name': 'Re/...    for_sale  394800
# 4     {'listing_office': {'list_item': {'name': 'Re/...    for_sale  130000
# ...                                                 ...         ...     ...
# 9757  {'listing_office': {'list_item': {'name': 'Re/...    for_sale   94900
# 9758  {'listing_office': {'list_item': {'name': 'Kel...    for_sale  149900
# 9759  {'listing_office': {'list_item': {'name': 'BHH...    for_sale  432990
# 9760  {'listing_office': {'list_item': {'name': 'Kel...    for_sale  405000
# 9761  {'listing_office': {'list_item': {'name': 'Hom...    for_sale  450000
#
#       baths_full  baths  beds                    building_size  \
# 0            3.0      3   6.0  {'size': 1632, 'units': 'sqft'}
# 1            1.0      1   3.0  {'size': 1092, 'units': 'sqft'}
# 2            1.0      2   3.0  {'size': 1360, 'units': 'sqft'}
# 3            1.0      2   3.0  {'size': 1856, 'units': 'sqft'}
# 4            1.0      2   3.0  {'size': 1180, 'units': 'sqft'}
# ...          ...    ...   ...                              ...
# 9757         1.0      1   4.0  {'size': 1296, 'units': 'sqft'}
# 9758         1.0      2   3.0  {'size': 1026, 'units': 'sqft'}
# 9759         3.0      4   3.0  {'size': 1614, 'units': 'sqft'}
# 9760         2.0      2   2.0  {'size': 1020, 'units': 'sqft'}
# 9761         3.0      3   4.0  {'size': 2600, 'units': 'sqft'}
#
#                                                  agents           last_update  \
# 0     [{'primary': True, 'advertiser_id': '1291281',...  2020-10-13T17:54:05Z
# 1     [{'primary': True, 'advertiser_id': '347285', ...  2020-10-13T18:18:18Z
# 2     [{'primary': True, 'photo': None, 'name': 'Kev...  2020-10-13T17:24:20Z
# 3     [{'primary': True, 'advertiser_id': '4759', 'i...  2020-10-13T17:11:54Z
# 4     [{'primary': True, 'advertiser_id': '391546', ...  2020-10-13T17:02:13Z
# ...                                                 ...                   ...
# 9757     [{'primary': True, 'photo': None, 'name': ''}]  2020-10-05T12:27:53Z
# 9758  [{'primary': True, 'advertiser_id': '950515', ...  2020-10-01T06:57:05Z
# 9759  [{'primary': True, 'advertiser_id': '948779', ...  2020-10-06T09:19:02Z
# 9760  [{'primary': True, 'advertiser_id': '2229603',...  2020-10-05T10:35:58Z
# 9761  [{'primary': True, 'advertiser_id': '3679690',...  2020-10-10T20:47:20Z
#
#       photo_count  page_no  rank                          lot_size  baths_half
# 0               9        1     1   {'size': 1842, 'units': 'sqft'}         NaN
# 1               7        1     2    {'size': 992, 'units': 'sqft'}         NaN
# 2              35        1     3   {'size': 1501, 'units': 'sqft'}         1.0
# 3             123        1     4  {'size': 15913, 'units': 'sqft'}         1.0
# 4              33        1     5   {'size': 1240, 'units': 'sqft'}         1.0
# ...           ...      ...   ...                               ...         ...
# 9757           18       42    33   {'size': 1064, 'units': 'sqft'}         NaN
# 9758           14       42    34   {'size': 1231, 'units': 'sqft'}         1.0
# 9759            2       42    35                               NaN         1.0
# 9760           25       42    36                               NaN         NaN
# 9761           24       42    37   {'size': 1200, 'units': 'sqft'}         NaN
#
# [9562 rows x 18 columns]

# %% [markdown]
# ## Reset index

# %%
processed_data = processed_data.reset_index(drop= True)
processed_data
# Out:
#       property_id      prop_type   prop_sub_type  \
# 0     M4046594895          condo  duplex_triplex
# 1     M3939384476          condo       townhomes
# 2     M4036371277          condo       townhomes
# 3     M3553029343  single_family             NaN
# 4     M3649199107          condo       townhomes
# ...           ...            ...             ...
# 9557  M3400474681          condo       townhomes
# 9558  M3654238233          condo       townhomes
# 9559  M9041602444          condo  duplex_triplex
# 9560  M3276555576          condo          condos
# 9561  M9041954204          condo       townhomes
#
#                                                 address  \
# 0     {'city': 'Philadelphia', 'line': '1516 N 62nd ...
# 1     {'city': 'Philadelphia', 'line': '6102 Reedlan...
# 2     {'city': 'Philadelphia', 'line': '5703 N 13th ...
# 3     {'city': 'Philadelphia', 'line': '1009 Rhawn S...
# 4     {'city': 'Philadelphia', 'line': '3850 N Bouvi...
# ...                                                 ...
# 9557  {'city': 'Philadelphia', 'line': '2077 Bridge ...
# 9558  {'city': 'Philadelphia', 'line': '1452 N 57th ...
# 9559  {'city': 'Philadelphia', 'line': '7354 Ridge A...
# 9560  {'city': 'Philadelphia', 'line': '1003 N Bodin...
# 9561  {'city': 'Philadelphia', 'line': '1524 S 25th ...
#
#                                                branding prop_status   price  \
# 0     {'listing_office': {'list_item': {'name': 'Arc...    for_sale  249900
# 1     {'listing_office': {'list_item': {'name': 'Vih...    for_sale  116800
# 2     {'listing_office': {'list_item': {'name': 'Pre...    for_sale  215000
# 3     {'listing_office': {'list_item': {'name': 'Re/...    for_sale  394800
# 4     {'listing_office': {'list_item': {'name': 'Re/...    for_sale  130000
# ...                                                 ...         ...     ...
# 9557  {'listing_office': {'list_item': {'name': 'Re/...    for_sale   94900
# 9558  {'listing_office': {'list_item': {'name': 'Kel...    for_sale  149900
# 9559  {'listing_office': {'list_item': {'name': 'BHH...    for_sale  432990
# 9560  {'listing_office': {'list_item': {'name': 'Kel...    for_sale  405000
# 9561  {'listing_office': {'list_item': {'name': 'Hom...    for_sale  450000
#
#       baths_full  baths  beds                    building_size  \
# 0            3.0      3   6.0  {'size': 1632, 'units': 'sqft'}
# 1            1.0      1   3.0  {'size': 1092, 'units': 'sqft'}
# 2            1.0      2   3.0  {'size': 1360, 'units': 'sqft'}
# 3            1.0      2   3.0  {'size': 1856, 'units': 'sqft'}
# 4            1.0      2   3.0  {'size': 1180, 'units': 'sqft'}
# ...          ...    ...   ...                              ...
# 9557         1.0      1   4.0  {'size': 1296, 'units': 'sqft'}
# 9558         1.0      2   3.0  {'size': 1026, 'units': 'sqft'}
# 9559         3.0      4   3.0  {'size': 1614, 'units': 'sqft'}
# 9560         2.0      2   2.0  {'size': 1020, 'units': 'sqft'}
# 9561         3.0      3   4.0  {'size': 2600, 'units': 'sqft'}
#
#                                                  agents           last_update  \
# 0     [{'primary': True, 'advertiser_id': '1291281',...  2020-10-13T17:54:05Z
# 1     [{'primary': True, 'advertiser_id': '347285', ...  2020-10-13T18:18:18Z
# 2     [{'primary': True, 'photo': None, 'name': 'Kev...  2020-10-13T17:24:20Z
# 3     [{'primary': True, 'advertiser_id': '4759', 'i...  2020-10-13T17:11:54Z
# 4     [{'primary': True, 'advertiser_id': '391546', ...  2020-10-13T17:02:13Z
# ...                                                 ...                   ...
# 9557     [{'primary': True, 'photo': None, 'name': ''}]  2020-10-05T12:27:53Z
# 9558  [{'primary': True, 'advertiser_id': '950515', ...  2020-10-01T06:57:05Z
# 9559  [{'primary': True, 'advertiser_id': '948779', ...  2020-10-06T09:19:02Z
# 9560  [{'primary': True, 'advertiser_id': '2229603',...  2020-10-05T10:35:58Z
# 9561  [{'primary': True, 'advertiser_id': '3679690',...  2020-10-10T20:47:20Z
#
#       photo_count  page_no  rank                          lot_size  baths_half
# 0               9        1     1   {'size': 1842, 'units': 'sqft'}         NaN
# 1               7        1     2    {'size': 992, 'units': 'sqft'}         NaN
# 2              35        1     3   {'size': 1501, 'units': 'sqft'}         1.0
# 3             123        1     4  {'size': 15913, 'units': 'sqft'}         1.0
# 4              33        1     5   {'size': 1240, 'units': 'sqft'}         1.0
# ...           ...      ...   ...                               ...         ...
# 9557           18       42    33   {'size': 1064, 'units': 'sqft'}         NaN
# 9558           14       42    34   {'size': 1231, 'units': 'sqft'}         1.0
# 9559            2       42    35                               NaN         1.0
# 9560           25       42    36                               NaN         NaN
# 9561           24       42    37   {'size': 1200, 'units': 'sqft'}         NaN
#
# [9562 rows x 18 columns]

# %%
## Export to csv file

processed_data.to_csv('processed_data.csv',encoding='utf-8', index=False)

# %% [markdown]
# # Extra more info within cols

# %%
## Check NaN in each col

processed_data.isna().sum()
# Out:
# property_id         0
# prop_type           0
# prop_sub_type    2512
# address             0
# branding            0
# prop_status         0
# price               0
# baths_full       1760
# baths               0
# beds             1182
# building_size    1381
# agents             94
# last_update         0
# photo_count         0
# page_no             0
# rank                0
# lot_size         1593
# baths_half       6168
# dtype: int64

# %%
processed_data['prop_sub_type'].unique()
# Out:
# array(['duplex_triplex', 'townhomes', nan, 'condos'], dtype=object)

# %%
import numpy as np

# %%
## extra dic type strings from col
import ast

def str_to_dic(string):
    if string == None: pass
    else:
        return ast.literal_eval(string)

# %%
def xtr_info_from_dict(col, level = 0, keys = []):
    if level == 0:
        for i in keys:

            if i not in col.keys(): return None
            else:
                col = col[i]
        return col        
    
    else:
        for i in keys:

            if i not in col[level-1].keys(): return None
            else:
                col = col[level-1][i]
        return col

# %%
l = []
for i in range(len(processed_data['agents'])):
    if str(processed_data['agents'][i]) == 'nan':
        l.append(None)
    else:
        l.append(xtr_info_from_dict(str_to_dic(processed_data['agents'][i]), level=0, keys = ['id']))

# %%
## function for extracting and converting info to df
def info_to_df(col, level, keys, df, col_name):
    l = []
    for i in range(len(col)):
        if str(col[i]) == 'nan':
            l.append(np.nan)
        else:
            l.append(xtr_info_from_dict(str_to_dic(col[i]), level = level, keys = keys))
    
    # convert list to df
    new_df = pd.DataFrame(l, columns=col_name)
    return new_df

# %%
## function: append col to df

def append_df(col, level, keys, col_name, df):
    
    new_df = info_to_df(col, level, keys, df, col_name)
    
    return df.join(new_df)

# %% [markdown]
# There are some cols have details such `address`, `branding`, `agents`, `lot_size`, and `mls`. We need to discuss what features should we extract from them.

# %%
append_df(col = processed_data['agents'], level = 0, keys = ['id'], df = processed_data, col_name = ['agent_id']).head()
# Out:
#    property_id      prop_type   prop_sub_type  \
# 0  M4046594895          condo  duplex_triplex
# 1  M3939384476          condo       townhomes
# 2  M4036371277          condo       townhomes
# 3  M3553029343  single_family             NaN
# 4  M3649199107          condo       townhomes
#
#                                              address  \
# 0  {'city': 'Philadelphia', 'line': '1516 N 62nd ...
# 1  {'city': 'Philadelphia', 'line': '6102 Reedlan...
# 2  {'city': 'Philadelphia', 'line': '5703 N 13th ...
# 3  {'city': 'Philadelphia', 'line': '1009 Rhawn S...
# 4  {'city': 'Philadelphia', 'line': '3850 N Bouvi...
#
#                                             branding prop_status   price  \
# 0  {'listing_office': {'list_item': {'name': 'Arc...    for_sale  249900
# 1  {'listing_office': {'list_item': {'name': 'Vih...    for_sale  116800
# 2  {'listing_office': {'list_item': {'name': 'Pre...    for_sale  215000
# 3  {'listing_office': {'list_item': {'name': 'Re/...    for_sale  394800
# 4  {'listing_office': {'list_item': {'name': 'Re/...    for_sale  130000
#
#    baths_full  baths  beds                    building_size  \
# 0         3.0      3   6.0  {'size': 1632, 'units': 'sqft'}
# 1         1.0      1   3.0  {'size': 1092, 'units': 'sqft'}
# 2         1.0      2   3.0  {'size': 1360, 'units': 'sqft'}
# 3         1.0      2   3.0  {'size': 1856, 'units': 'sqft'}
# 4         1.0      2   3.0  {'size': 1180, 'units': 'sqft'}
#
#                                               agents           last_update  \
# 0  [{'primary': True, 'advertiser_id': '1291281',...  2020-10-13T17:54:05Z
# 1  [{'primary': True, 'advertiser_id': '347285', ...  2020-10-13T18:18:18Z
# 2  [{'primary': True, 'photo': None, 'name': 'Kev...  2020-10-13T17:24:20Z
# 3  [{'primary': True, 'advertiser_id': '4759', 'i...  2020-10-13T17:11:54Z
# 4  [{'primary': True, 'advertiser_id': '391546', ...  2020-10-13T17:02:13Z
#
#    photo_count  page_no  rank                          lot_size  baths_half  \
# 0            9        1     1   {'size': 1842, 'units': 'sqft'}         NaN
# 1            7        1     2    {'size': 992, 'units': 'sqft'}         NaN
# 2           35        1     3   {'size': 1501, 'units': 'sqft'}         1.0
# 3          123        1     4  {'size': 15913, 'units': 'sqft'}         1.0
# 4           33        1     5   {'size': 1240, 'units': 'sqft'}         1.0
#
#   agent_id
# 0  1291281
# 1   347285
# 2     None
# 3     4759
# 4   391546

# %%
str_to_dic(processed_data['branding'][0])['listing_office']['list_item']['name']
# Out:
# 'Archstone Realty'

# %%
len(processed_data['branding'])
# Out:
# 9562

# %%
## copy df
update_df = processed_data.copy()

# %%
extract = {'address':['city', 'line', 'postal_code', 'state_code', 'county', 'lat', 'lon', 'neighborhood_name'],
           'building_size':['size']
          }

# %%
for k in extract:
    for info in extract[k]:
        update_df = append_df(col = update_df[k], level = 0, keys = [info], df = update_df, col_name = [info])

# %%
## rename building size
update_df = update_df.rename(columns={'size':'buiding_size(sqft)'})

# %%
## get lot size
update_df = append_df(col = update_df['lot_size'], level = 0, keys = ['size'], df = update_df, col_name = ['lot_size(sqft)'])

# %%
## get agent id
update_df = append_df(col = update_df['agents'], level = 1, keys = ['id'], df = update_df, col_name = ['agent_id'])

# %%
## get agent name
update_df = append_df(col = update_df['agents'], level = 1, keys = ['name'], df = update_df, col_name = ['agent_name'])

# %%
## get branding office name
brand_name = []
for i in range(len(processed_data['branding'])):
    if str(processed_data['branding'][i]) == 'nan':
        brand_name.append(np.nan)
    else:
        brand_name.append(str_to_dic(processed_data['branding'][i])['listing_office']['list_item']['name'])
    
# convert list to df
brand_name = pd.DataFrame(brand_name, columns=['brand_name'])

update_df = update_df.join(brand_name)

# %%
## drop original cols
update_df.drop(columns=['address', 'building_size', 'agents', 'branding', 'lot_size'], inplace=True)

# %%
update_df.head()
# Out:
#    property_id      prop_type   prop_sub_type prop_status   price  baths_full  \
# 0  M4046594895          condo  duplex_triplex    for_sale  249900         3.0
# 1  M3939384476          condo       townhomes    for_sale  116800         1.0
# 2  M4036371277          condo       townhomes    for_sale  215000         1.0
# 3  M3553029343  single_family             NaN    for_sale  394800         1.0
# 4  M3649199107          condo       townhomes    for_sale  130000         1.0
#
#    baths  beds           last_update  photo_count  ...  state_code  \
# 0      3   6.0  2020-10-13T17:54:05Z            9  ...          PA
# 1      1   3.0  2020-10-13T18:18:18Z            7  ...          PA
# 2      2   3.0  2020-10-13T17:24:20Z           35  ...          PA
# 3      2   3.0  2020-10-13T17:11:54Z          123  ...          PA
# 4      2   3.0  2020-10-13T17:02:13Z           33  ...          PA
#
#          county        lat        lon            neighborhood_name  \
# 0  Philadelphia  39.974408 -75.243700            West Philadelphia
# 1  Philadelphia  39.926283 -75.225382       Southwest Philadelphia
# 2  Philadelphia  40.039721 -75.142100         Upper North District
# 3  Philadelphia  40.071978 -75.073303  Near Northeast Philadelphia
# 4  Philadelphia  40.012784 -75.156405     Upper North Philadelphia
#
#   buiding_size(sqft) lot_size(sqft) agent_id           agent_name  \
# 0             1632.0         1842.0  1291281     Ausra Anusauskas
# 1             1092.0          992.0   347285           Dr Hanh Vo
# 2             1360.0         1501.0     None           Kevin Chen
# 3             1856.0        15913.0     4759         Carol Mallen
# 4             1180.0         1240.0   391546  Maria Quattrone CEO
#
#                      brand_name
# 0              Archstone Realty
# 1                   Vihi Realty
# 2     Premium Realty Castor Inc
# 3               Re/Max Services
# 4  Re/Max @ Home - Philadelphia
#
# [5 rows x 26 columns]

# %%
update_df.isna().sum()
# Out:
# property_id              0
# prop_type                0
# prop_sub_type         2512
# prop_status              0
# price                    0
# baths_full            1760
# baths                    0
# beds                  1182
# last_update              0
# photo_count              0
# page_no                  0
# rank                     0
# baths_half            6168
# city                     0
# line                     9
# postal_code              0
# state_code               0
# county                   0
# lat                      0
# lon                      0
# neighborhood_name        8
# buiding_size(sqft)    1381
# lot_size(sqft)        1687
# agent_id               986
# agent_name             174
# brand_name              80
# dtype: int64

# %%
## export to csv
# update_df.to_csv('update_df.csv',encoding='utf-8', index=False)

# %%
update_df.shape
# Out:
# (9562, 26)
