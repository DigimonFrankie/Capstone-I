# %% [markdown]
# # COVID Cases, Hospitalizations, and Deaths by Age, Sex, Race, and Date.
# #### Data acquired from [opendataphilly.org](https://www.opendataphilly.org).
# #### Coding & Analysis: Lawrence Love
# * Notebook last updated 11/20/2020
#     * Removed all cells reading in CSVs and replace with API calls
#     * Using API changed the representation of dates which required regex to clean
#     * Final corrections for better plotting and code readability

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import calendar
import json
import requests
import re

# %%
# Cases by Age
url = 'https://phl.carto.com/api/v2/sql?q=SELECT * FROM covid_cases_by_age'
response = requests.request("GET", url)
cases_age = pd.json_normalize(response.json()['rows'])

# %%
# Cases by Sex
url = 'https://phl.carto.com/api/v2/sql?q=SELECT * FROM covid_cases_by_sex'
response = requests.request("GET", url)
cases_sex = pd.json_normalize(response.json()['rows'])

# %%
# Hospitalizations by Age
url = 'https://phl.carto.com/api/v2/sql?q=SELECT * FROM covid_hospitalizations_by_age'
response = requests.request("GET", url)
hosp_age = pd.json_normalize(response.json()['rows'])

# %%
# Hospitalizations by Sex
url = 'https://phl.carto.com/api/v2/sql?q=SELECT * FROM covid_hospitalizations_by_sex'
response = requests.request("GET", url)
hosp_sex = pd.json_normalize(response.json()['rows'])

# %%
# Deaths by Age
url = 'https://phl.carto.com/api/v2/sql?q=SELECT * FROM covid_deaths_by_age'
response = requests.request("GET", url)
deaths_age = pd.json_normalize(response.json()['rows'])

# %%
# Cases by Race
url = 'https://phl.carto.com/api/v2/sql?q=SELECT * FROM covid_cases_by_race'
response = requests.request("GET", url)
cases_race = pd.json_normalize(response.json()['rows'])

# %%
# Hospitalizations by Race
url = 'https://phl.carto.com/api/v2/sql?q=SELECT * FROM covid_hospitalizations_by_race'
response = requests.request("GET", url)
hosp_race = pd.json_normalize(response.json()['rows'])

# %%
# Deaths by Race
url = 'https://phl.carto.com/api/v2/sql?q=SELECT * FROM covid_deaths_by_race'
response = requests.request("GET", url)
deaths_race = pd.json_normalize(response.json()['rows'])

# %%
# Cases by Date
url = 'https://phl.carto.com/api/v2/sql?q=SELECT * FROM covid_cases_by_date'
response = requests.request("GET", url)
cases_date = pd.json_normalize(response.json()['rows'])

# %%
# Hospitalizations by Date
url = 'https://phl.carto.com/api/v2/sql?q=SELECT * FROM covid_hospitalizations_by_date'
response = requests.request("GET", url)
hosp_date = pd.json_normalize(response.json()['rows'])

# %%
# Deaths by Date
url = 'https://phl.carto.com/api/v2/sql?q=SELECT * FROM covid_deaths_by_date'
response = requests.request("GET", url)
deaths_date = pd.json_normalize(response.json()['rows'])

# %% [markdown]
# ## Cases by Age/Sex

# %%
cases_age
# Out:
#    cartodb_id the_geom the_geom_webmercator    age  count  \
# 0           1     None                 None  20-34  18286
# 1           2     None                 None  55-74  12938
# 2           3     None                 None    75+   4418
# 3           4     None                 None    <20   5838
# 4           5     None                 None  35-54  17571
#
#           etl_timestamp
# 0  2020-11-20T18:20:02Z
# 1  2020-11-20T18:20:02Z
# 2  2020-11-20T18:20:02Z
# 3  2020-11-20T18:20:02Z
# 4  2020-11-20T18:20:02Z

# %%
# Reorder the ages youngest to oldest
cases_age = cases_age.loc[[3, 0, 4, 1, 2], :]

# %%
ages = [i for i in cases_age['age']]
plt.figure(figsize=(10,6))
plt.title('Cases by Age')
case_age_plot = sns.barplot(x='age', y='count', data=cases_age)
case_age_plot.set_xticklabels(ages, rotation=45)
plt.show()

# %%
cases_sex
# Out:
#    cartodb_id the_geom the_geom_webmercator      sex  count  \
# 0           1     None                 None   Female  32276
# 1           2     None                 None     Male  26485
# 2           3     None                 None  UNKNOWN    320
#
#           etl_timestamp
# 0  2020-11-20T18:20:02Z
# 1  2020-11-20T18:20:02Z
# 2  2020-11-20T18:20:02Z

# %%
# Make 'UNKNOWN' casing consistent with other responses
cases_sex.loc[cases_sex['sex'] == 'UNKNOWN', ['sex']] = 'Unknown'

# %%
sexes = [i for i in cases_sex['sex']]
plt.figure(figsize=(10,6))
plt.title('Cases by Sex')
case_sex_plot = sns.barplot(x='sex', y='count', data=cases_sex)
case_sex_plot.set_xticklabels(sexes, rotation=45)
plt.show()

# %% [markdown]
# ## Hospitalizations by Age/Sex

# %%
hosp_age
# Out:
#    cartodb_id the_geom the_geom_webmercator    age hospitalized  count  \
# 0           1     None                 None    <20          Yes    154
# 1           2     None                 None    75+   NO_UNKNOWN   2541
# 2           3     None                 None    <20   NO_UNKNOWN   5684
# 3           4     None                 None  55-74   NO_UNKNOWN   9580
# 4           5     None                 None  35-54   NO_UNKNOWN  15655
# 5           6     None                 None  55-74          Yes   3358
# 6           7     None                 None  20-34   NO_UNKNOWN  17395
# 7           8     None                 None  20-34          Yes    891
# 8           9     None                 None  35-54          Yes   1916
# 9          10     None                 None    75+          Yes   1877
#
#           etl_timestamp
# 0  2020-11-20T18:20:02Z
# 1  2020-11-20T18:20:02Z
# 2  2020-11-20T18:20:02Z
# 3  2020-11-20T18:20:02Z
# 4  2020-11-20T18:20:02Z
# 5  2020-11-20T18:20:02Z
# 6  2020-11-20T18:20:02Z
# 7  2020-11-20T18:20:02Z
# 8  2020-11-20T18:20:02Z
# 9  2020-11-20T18:20:02Z

# %%
# Make 'NO_UNKNOWN' more presentable and consistent with other responses
hosp_age.loc[hosp_age['hospitalized'] == 'NO_UNKNOWN', ['hospitalized']] = 'No_or_Unk'

# %%
# Set and reorder ages younges to oldest
ages_order = ['<20', '20-34', '35-54', '55-74', '75+']
hosp_age['age'] = pd.Categorical(hosp_age['age'], categories=ages_order, ordered=True)

# %%
hosp_age_plot = sns.catplot(x = "age", y = "count", hue = "hospitalized", data=hosp_age, kind = "bar", height=6)
hosp_age_plot.fig.suptitle('Hospitalizations by Age')
plt.show()

# %%
hosp_sex
# Out:
#    cartodb_id the_geom the_geom_webmercator     sex hospitalized  count  \
# 0           1     None                 None  Female          Yes   4078
# 1           2     None                 None    Male          Yes   4120
# 2           3     None                 None  Female   NO_UNKNOWN  28198
# 3           4     None                 None    Male   NO_UNKNOWN  22365
#
#           etl_timestamp
# 0  2020-11-20T18:20:02Z
# 1  2020-11-20T18:20:02Z
# 2  2020-11-20T18:20:02Z
# 3  2020-11-20T18:20:02Z

# %%
# Make 'NO_UNKNOWN' more presentable and consistent with other responses
hosp_sex.loc[hosp_sex['hospitalized'] == 'NO_UNKNOWN', ['hospitalized']] = 'No_or_Unk'

# %%
hosp_sex_plot = sns.catplot(x = "hospitalized", y = "count", hue = "sex", data=hosp_sex, kind = "bar", height=6)
hosp_sex_plot.fig.suptitle('Hospitalizations by Sex')
plt.show()

# %% [markdown]
# ### Deaths by Age/Sex

# %%
deaths_age
# Out:
#    cartodb_id the_geom the_geom_webmercator  gender    age  count  \
# 0           1     None                 None    Male  20-34     10
# 1           2     None                 None    Male  35-54     92
# 2           3     None                 None  Female  55-74    297
# 3           4     None                 None  Female    75+    604
# 4           5     None                 None    Male  55-74    424
# 5           6     None                 None  Female  35-54     45
# 6           7     None                 None    Male    75+    473
#
#           etl_timestamp
# 0  2020-11-20T18:20:02Z
# 1  2020-11-20T18:20:02Z
# 2  2020-11-20T18:20:02Z
# 3  2020-11-20T18:20:02Z
# 4  2020-11-20T18:20:02Z
# 5  2020-11-20T18:20:02Z
# 6  2020-11-20T18:20:02Z

# %%
# No entries for 'Female' 'Age = 20-34'. Perhaps no such cases at this time in Philadelphia? Seems hard to believe.
deaths_age.sort_values('age')
# Out:
#    cartodb_id the_geom the_geom_webmercator  gender    age  count  \
# 0           1     None                 None    Male  20-34     10
# 1           2     None                 None    Male  35-54     92
# 5           6     None                 None  Female  35-54     45
# 2           3     None                 None  Female  55-74    297
# 4           5     None                 None    Male  55-74    424
# 3           4     None                 None  Female    75+    604
# 6           7     None                 None    Male    75+    473
#
#           etl_timestamp
# 0  2020-11-20T18:20:02Z
# 1  2020-11-20T18:20:02Z
# 5  2020-11-20T18:20:02Z
# 2  2020-11-20T18:20:02Z
# 4  2020-11-20T18:20:02Z
# 3  2020-11-20T18:20:02Z
# 6  2020-11-20T18:20:02Z

# %%
age_plot = sns.catplot(x = "age", y = "count", hue = "gender", data=deaths_age, kind = "bar", height=6)
age_plot.fig.suptitle('Deaths by Age and Sex')
plt.show()

# %% [markdown]
# __________________

# %% [markdown]
# ## Cases by Race

# %%
cases_race
# Out:
#     cartodb_id the_geom the_geom_webmercator   racial_identity  count  \
# 0            1     None                 None             White  12946
# 1            2     None                 None   AMERICAN INDIAN      1
# 2            3     None                 None              None   9370
# 3            4     None                 None             OTHER   3117
# 4            5     None                 None           DECLINE      1
# 5            6     None                 None           African      9
# 6            7     None                 None  Pacific Islander     32
# 7            8     None                 None   Native American     62
# 8            9     None                 None           UNKNOWN    574
# 9           10     None                 None             Asian   2199
# 10          11     None                 None          HISPANIC   7210
# 11          12     None                 None  African American  23244
# 12          13     None                 None             BLACK    316
#
#            etl_timestamp
# 0   2020-11-20T18:20:02Z
# 1   2020-11-20T18:20:02Z
# 2   2020-11-20T18:20:02Z
# 3   2020-11-20T18:20:02Z
# 4   2020-11-20T18:20:02Z
# 5   2020-11-20T18:20:02Z
# 6   2020-11-20T18:20:02Z
# 7   2020-11-20T18:20:02Z
# 8   2020-11-20T18:20:02Z
# 9   2020-11-20T18:20:02Z
# 10  2020-11-20T18:20:02Z
# 11  2020-11-20T18:20:02Z
# 12  2020-11-20T18:20:02Z

# %%
# We'll combine the 'None', and 'DECLINE' with ' UNKNOWN'
# Sort the responses by count and reset the index
cases_race['count'][8] = (cases_race['count'][4] + cases_race['count'][2] + cases_race['count'][8])
cases_race.drop([2,4], inplace=True)
cases_race = cases_race.sort_values('count', ascending=False)
cases_race = cases_race.reset_index(drop=True)
# Out:
# /Users/lawrencelove/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Fix 'racial_identity' casing inconsitencies.
cases_race['racial_identity'] = cases_race['racial_identity'].str.title()

# %%
races = [i for i in cases_race['racial_identity']]
plt.figure(figsize=(10,6))
plt.title('Cases by Race')
case_race_plot = sns.barplot(x='racial_identity', y='count', data=cases_race)
case_race_plot.set_xticklabels(races, rotation=45)
plt.show()

# %%
# Show percentage of cases by Race
cases_race_perc = []
for i in cases_race['count']:
    cases_race_perc.append(round(i / cases_race['count'].sum(),4))

cases_race['percent_of_total_cases'] = cases_race_perc
cases_race[['racial_identity', 'percent_of_total_cases']]
# Out:
#      racial_identity  percent_of_total_cases
# 0   African American                  0.3934
# 1              White                  0.2191
# 2            Unknown                  0.1683
# 3           Hispanic                  0.1220
# 4              Other                  0.0528
# 5              Asian                  0.0372
# 6              Black                  0.0053
# 7    Native American                  0.0010
# 8   Pacific Islander                  0.0005
# 9            African                  0.0002
# 10   American Indian                  0.0000

# %% [markdown]
# ## Hospitalizations by Race

# %%
hosp_race
# Out:
#     cartodb_id the_geom the_geom_webmercator   racial_identity hospitalized  \
# 0            1     None                 None          HISPANIC          Yes
# 1            2     None                 None             White          Yes
# 2            3     None                 None           UNKNOWN   NO_UNKNOWN
# 3            4     None                 None   Native American   NO_UNKNOWN
# 4            5     None                 None             Asian   NO_UNKNOWN
# 5            6     None                 None  AFRICAN AMERICAN   NO_UNKNOWN
# 6            7     None                 None             WHITE   NO_UNKNOWN
# 7            8     None                 None           UNKNOWN          Yes
# 8            9     None                 None  AFRICAN AMERICAN          Yes
# 9           10     None                 None              None          Yes
# 10          11     None                 None              None   NO_UNKNOWN
# 11          12     None                 None   Native American          Yes
# 12          13     None                 None          HISPANIC   NO_UNKNOWN
# 13          14     None                 None             Asian          Yes
# 14          15     None                 None           DECLINE   NO_UNKNOWN
# 15          16     None                 None   AMERICAN INDIAN   NO_UNKNOWN
# 16          17     None                 None  Pacific Islander          Yes
# 17          18     None                 None             OTHER          Yes
# 18          19     None                 None  PACIFIC ISLANDER   NO_UNKNOWN
# 19          20     None                 None             OTHER   NO_UNKNOWN
#
#     count         etl_timestamp
# 0    1238  2020-11-20T18:20:02Z
# 1    1549  2020-11-20T18:20:02Z
# 2     502  2020-11-20T18:20:02Z
# 3      57  2020-11-20T18:20:02Z
# 4    1882  2020-11-20T18:20:02Z
# 5   18994  2020-11-20T18:20:02Z
# 6   11397  2020-11-20T18:20:02Z
# 7      72  2020-11-20T18:20:02Z
# 8    4566  2020-11-20T18:20:02Z
# 9     103  2020-11-20T18:20:02Z
# 10   9267  2020-11-20T18:20:02Z
# 11      5  2020-11-20T18:20:02Z
# 12   5972  2020-11-20T18:20:02Z
# 13    317  2020-11-20T18:20:02Z
# 14      1  2020-11-20T18:20:02Z
# 15      1  2020-11-20T18:20:02Z
# 16      7  2020-11-20T18:20:02Z
# 17    342  2020-11-20T18:20:02Z
# 18     25  2020-11-20T18:20:02Z
# 19   2784  2020-11-20T18:20:02Z

# %%
# Fix cases inconsitencies
hosp_race['racial_identity'] = hosp_race['racial_identity'].str.title()
# Make 'NO_UNKNOWN' more presentable with 'No_or_Unk'
hosp_race.loc[hosp_race['hospitalized'] == 'NO_UNKNOWN', ['hospitalized']] = 'No_or_Unk'

# %%
# Combine the NaNs with 'UNKNOWN' and confirm total count is the same before and after.
# Sort the responses by count and reset the index
print('Before edits =', hosp_race['count'].sum())
hosp_race['count'][2] = (hosp_race['count'][2] + hosp_race['count'][10] + hosp_race['count'][14])
hosp_race['count'][7] = (hosp_race['count'][7] + hosp_race['count'][9])
hosp_race.drop([9,10,14], inplace=True)
hosp_race = hosp_race.sort_values('count', ascending=False)
hosp_race = hosp_race.reset_index(drop=True)
print('After edits =', hosp_race['count'].sum())
# Out:
# Before edits = 59081
# After edits = 59081
# /Users/lawrencelove/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/lawrencelove/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
hosp_race
# Out:
#     cartodb_id the_geom the_geom_webmercator   racial_identity hospitalized  \
# 0            6     None                 None  African American    No_or_Unk
# 1            7     None                 None             White    No_or_Unk
# 2            3     None                 None           Unknown    No_or_Unk
# 3           13     None                 None          Hispanic    No_or_Unk
# 4            9     None                 None  African American          Yes
# 5           20     None                 None             Other    No_or_Unk
# 6            5     None                 None             Asian    No_or_Unk
# 7            2     None                 None             White          Yes
# 8            1     None                 None          Hispanic          Yes
# 9           18     None                 None             Other          Yes
# 10          14     None                 None             Asian          Yes
# 11           8     None                 None           Unknown          Yes
# 12           4     None                 None   Native American    No_or_Unk
# 13          19     None                 None  Pacific Islander    No_or_Unk
# 14          17     None                 None  Pacific Islander          Yes
# 15          12     None                 None   Native American          Yes
# 16          16     None                 None   American Indian    No_or_Unk
#
#     count         etl_timestamp
# 0   18994  2020-11-20T18:20:02Z
# 1   11397  2020-11-20T18:20:02Z
# 2    9770  2020-11-20T18:20:02Z
# 3    5972  2020-11-20T18:20:02Z
# 4    4566  2020-11-20T18:20:02Z
# 5    2784  2020-11-20T18:20:02Z
# 6    1882  2020-11-20T18:20:02Z
# 7    1549  2020-11-20T18:20:02Z
# 8    1238  2020-11-20T18:20:02Z
# 9     342  2020-11-20T18:20:02Z
# 10    317  2020-11-20T18:20:02Z
# 11    175  2020-11-20T18:20:02Z
# 12     57  2020-11-20T18:20:02Z
# 13     25  2020-11-20T18:20:02Z
# 14      7  2020-11-20T18:20:02Z
# 15      5  2020-11-20T18:20:02Z
# 16      1  2020-11-20T18:20:02Z

# %%
hosp_race_plot = sns.catplot(x = "racial_identity", y = "count", hue = "hospitalized", data=hosp_race,
                             kind = "bar", height=6)
hosp_race_plot.fig.suptitle('Hospitalizations by Race')
hosp_race_plot.set_xticklabels(rotation=45)
plt.show()

# %% [markdown]
# ## Deaths by Race

# %%
deaths_race
# Out:
#    cartodb_id the_geom the_geom_webmercator   racial_identity  count  \
# 0           1     None                 None              None     92
# 1           2     None                 None             Asian     68
# 2           3     None                 None           UNKNOWN     33
# 3           4     None                 None  AFRICAN AMERICAN    952
# 4           5     None                 None             Other     54
# 5           6     None                 None          HISPANIC    180
# 6           7     None                 None             White    570
#
#           etl_timestamp
# 0  2020-11-20T18:20:02Z
# 1  2020-11-20T18:20:02Z
# 2  2020-11-20T18:20:02Z
# 3  2020-11-20T18:20:02Z
# 4  2020-11-20T18:20:02Z
# 5  2020-11-20T18:20:02Z
# 6  2020-11-20T18:20:02Z

# %%
# No real explanation for 'NaN' row here, we'll just combine 'UNKNOWN' with NaN row.
# Fix 'racial_identity' casing inconsitencies.
# Sort the responses by count and reset the index
deaths_race['racial_identity'] = deaths_race['racial_identity'].str.title()
deaths_race['count'][2] = (deaths_race['count'][2] + deaths_race['count'][0])
deaths_race.drop([0], inplace=True)
deaths_race = deaths_race.sort_values('count', ascending=False)
deaths_race = deaths_race.reset_index(drop=True)
deaths_race
# Out:
# /Users/lawrencelove/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#    cartodb_id the_geom the_geom_webmercator   racial_identity  count  \
# 0           4     None                 None  African American    952
# 1           7     None                 None             White    570
# 2           6     None                 None          Hispanic    180
# 3           3     None                 None           Unknown    125
# 4           2     None                 None             Asian     68
# 5           5     None                 None             Other     54
#
#           etl_timestamp
# 0  2020-11-20T18:20:02Z
# 1  2020-11-20T18:20:02Z
# 2  2020-11-20T18:20:02Z
# 3  2020-11-20T18:20:02Z
# 4  2020-11-20T18:20:02Z
# 5  2020-11-20T18:20:02Z

# %%
races = [i for i in deaths_race['racial_identity']]
plt.figure(figsize=(10,6))
plt.title('Deaths by Race')
race_plot = sns.barplot(x='racial_identity', y='count', data=deaths_race)
race_plot.set_xticklabels(races, rotation=45)
plt.show()

# %% [markdown]
# ----------------

# %% [markdown]
# ## Cases by Date

# %%
cases_date
# Out:
#      cartodb_id the_geom the_geom_webmercator       collection_date  count  \
# 0             1     None                 None  2020-10-10T00:00:00Z   4627
# 1             2     None                 None  2020-05-24T00:00:00Z     98
# 2             3     None                 None  2020-06-06T00:00:00Z   1319
# 3             4     None                 None  2020-09-27T00:00:00Z     80
# 4             5     None                 None  2020-11-03T00:00:00Z    614
# ..          ...      ...                  ...                   ...    ...
# 507         508     None                 None  2020-03-21T00:00:00Z    188
# 508         509     None                 None  2020-09-05T00:00:00Z     69
# 509         510     None                 None  2020-04-25T00:00:00Z    959
# 510         511     None                 None  2020-03-14T00:00:00Z     14
# 511         512     None                 None  2020-07-13T00:00:00Z   2512
#
#     test_result         etl_timestamp
# 0      negative  2020-11-20T18:20:02Z
# 1      positive  2020-11-20T18:20:02Z
# 2      negative  2020-11-20T18:20:02Z
# 3      positive  2020-11-20T18:20:02Z
# 4      positive  2020-11-20T18:20:02Z
# ..          ...                   ...
# 507    negative  2020-11-20T18:20:02Z
# 508    positive  2020-11-20T18:20:02Z
# 509    negative  2020-11-20T18:20:02Z
# 510    positive  2020-11-20T18:20:02Z
# 511    negative  2020-11-20T18:20:02Z
#
# [512 rows x 7 columns]

# %%
cases_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   cartodb_id            512 non-null    int64
#  1   the_geom              0 non-null      object
#  2   the_geom_webmercator  0 non-null      object
#  3   collection_date       512 non-null    object
#  4   count                 512 non-null    int64
#  5   test_result           512 non-null    object
#  6   etl_timestamp         512 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 28.1+ KB

# %%
# Remove 'T00:00:00Z' from 'collection_date'
cases_date['collection_date'] =  [re.sub('T(.*?)Z','', str(x)) for x in cases_date['collection_date']]

# %%
cases_date
# Out:
#      cartodb_id the_geom the_geom_webmercator collection_date  count  \
# 0             1     None                 None      2020-10-10   4627
# 1             2     None                 None      2020-05-24     98
# 2             3     None                 None      2020-06-06   1319
# 3             4     None                 None      2020-09-27     80
# 4             5     None                 None      2020-11-03    614
# ..          ...      ...                  ...             ...    ...
# 507         508     None                 None      2020-03-21    188
# 508         509     None                 None      2020-09-05     69
# 509         510     None                 None      2020-04-25    959
# 510         511     None                 None      2020-03-14     14
# 511         512     None                 None      2020-07-13   2512
#
#     test_result         etl_timestamp
# 0      negative  2020-11-20T18:20:02Z
# 1      positive  2020-11-20T18:20:02Z
# 2      negative  2020-11-20T18:20:02Z
# 3      positive  2020-11-20T18:20:02Z
# 4      positive  2020-11-20T18:20:02Z
# ..          ...                   ...
# 507    negative  2020-11-20T18:20:02Z
# 508    positive  2020-11-20T18:20:02Z
# 509    negative  2020-11-20T18:20:02Z
# 510    positive  2020-11-20T18:20:02Z
# 511    negative  2020-11-20T18:20:02Z
#
# [512 rows x 7 columns]

# %%
# Add months to the data set and group by month to get a month by month analysis.
months = []
for i in cases_date['collection_date']:
    months.append(datetime.datetime.strptime(i, "%Y-%m-%d").month)
    
month_names = []
for i in months:
    month_names.append(calendar.month_abbr[i])

cases_date['month'] = month_names

new_cases_date = cases_date.groupby(['month', 'test_result'], as_index=False).sum()
new_cases_date.drop(['cartodb_id'], axis=1, inplace=True)
new_cases_date
# Out:
#    month test_result   count
# 0    Apr    negative   28825
# 1    Apr    positive   12911
# 2    Aug    negative  103596
# 3    Aug    positive    3640
# 4    Jul    negative   89972
# 5    Jul    positive    4316
# 6    Jun    negative   63332
# 7    Jun    positive    3477
# 8    Mar    negative    7716
# 9    Mar    positive    3202
# 10   May    negative   49556
# 11   May    positive    7057
# 12   Nov    negative  108509
# 13   Nov    positive   12692
# 14   Oct    negative  157249
# 15   Oct    positive    8554
# 16   Sep    negative  111557
# 17   Sep    positive    3034

# %%
# Set and reorder months
months_order = ['Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov']
new_cases_date['month'] = pd.Categorical(new_cases_date['month'], categories=months_order, ordered=True)

# %%
cases_date_plot = sns.catplot(x = "month", y = "count", hue = "test_result", data=new_cases_date, kind = "bar", height=6)
cases_date_plot.fig.suptitle('Cases by Month')
plt.show()

# %% [markdown]
# ## Hospitalizations by Date

# %%
hosp_date
# Out:
#      cartodb_id the_geom the_geom_webmercator                  date  \
# 0             1     None                 None  2020-10-21T00:00:00Z
# 1             2     None                 None  2020-06-01T00:00:00Z
# 2             3     None                 None  2020-10-30T00:00:00Z
# 3             4     None                 None  2020-06-04T00:00:00Z
# 4             5     None                 None  2020-04-10T00:00:00Z
# ..          ...      ...                  ...                   ...
# 480         481     None                 None  2020-06-26T00:00:00Z
# 481         482     None                 None  2020-08-23T00:00:00Z
# 482         483     None                 None  2020-05-20T00:00:00Z
# 483         484     None                 None  2020-04-24T00:00:00Z
# 484         485     None                 None  2020-09-30T00:00:00Z
#
#     hospitalized  count         etl_timestamp
# 0     NO_UNKNOWN    311  2020-11-20T18:20:02Z
# 1     NO_UNKNOWN     72  2020-11-20T18:20:02Z
# 2            Yes     18  2020-11-20T18:20:02Z
# 3            Yes     23  2020-11-20T18:20:02Z
# 4     NO_UNKNOWN    449  2020-11-20T18:20:02Z
# ..           ...    ...                   ...
# 480   NO_UNKNOWN     73  2020-11-20T18:20:02Z
# 481          Yes      8  2020-11-20T18:20:02Z
# 482   NO_UNKNOWN    174  2020-11-20T18:20:02Z
# 483          Yes    107  2020-11-20T18:20:02Z
# 484   NO_UNKNOWN    151  2020-11-20T18:20:02Z
#
# [485 rows x 7 columns]

# %%
hosp_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485 entries, 0 to 484
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   cartodb_id            485 non-null    int64
#  1   the_geom              0 non-null      object
#  2   the_geom_webmercator  0 non-null      object
#  3   date                  483 non-null    object
#  4   hospitalized          485 non-null    object
#  5   count                 485 non-null    int64
#  6   etl_timestamp         485 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 26.6+ KB

# %%
hosp_date.sort_values('date') # Sorting shows the NaN, and tells us where the dataset ends and begins.
                              # We'll just assume these NaNs come from dates prior to data collection, 
                              # and thus give them the date '2020-03-01'.
# Out:
#      cartodb_id the_geom the_geom_webmercator                  date  \
# 318         319     None                 None  2020-03-14T00:00:00Z
# 40           41     None                 None  2020-03-17T00:00:00Z
# 65           66     None                 None  2020-03-18T00:00:00Z
# 124         125     None                 None  2020-03-19T00:00:00Z
# 170         171     None                 None  2020-03-19T00:00:00Z
# ..          ...      ...                  ...                   ...
# 142         143     None                 None  2020-11-17T00:00:00Z
# 433         434     None                 None  2020-11-18T00:00:00Z
# 306         307     None                 None  2020-11-19T00:00:00Z
# 166         167     None                 None                  None
# 258         259     None                 None                  None
#
#     hospitalized  count         etl_timestamp
# 318   NO_UNKNOWN      5  2020-11-20T18:20:02Z
# 40    NO_UNKNOWN     13  2020-11-20T18:20:02Z
# 65    NO_UNKNOWN      7  2020-11-20T18:20:02Z
# 124   NO_UNKNOWN     27  2020-11-20T18:20:02Z
# 170          Yes      5  2020-11-20T18:20:02Z
# ..           ...    ...                   ...
# 142   NO_UNKNOWN    930  2020-11-20T18:20:02Z
# 433   NO_UNKNOWN    688  2020-11-20T18:20:02Z
# 306   NO_UNKNOWN    368  2020-11-20T18:20:02Z
# 166          Yes     28  2020-11-20T18:20:02Z
# 258   NO_UNKNOWN    331  2020-11-20T18:20:02Z
#
# [485 rows x 7 columns]

# %%
# Remove 'T00:00:00Z' from 'date'
hosp_date['date'] =  [re.sub('T(.*?)Z','', str(x)) for x in hosp_date['date']]

# %%
# Replace 'None' with '2020-03-01'
for i in range(0, len(hosp_date['date'])):
    if hosp_date['date'][i] == 'None':
        hosp_date['date'][i] = '2020-03-01'
# Out:
# /Users/lawrencelove/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# Add months to the data set and group by month to get a month by month analysis.
months = []
for i in hosp_date['date']:
    months.append(datetime.datetime.strptime(i, "%Y-%m-%d").month)

month_names = []
for i in months:
    month_names.append(calendar.month_abbr[i])

hosp_date['month'] = month_names

new_hosp_date = hosp_date.groupby(['month', 'hospitalized'], as_index=False).sum()

new_hosp_date.loc[new_hosp_date['hospitalized'] == 'NO_UNKNOWN', ['hospitalized']] = 'No_or_Unk'
new_hosp_date
# Out:
#    month hospitalized  cartodb_id  count
# 0    Apr    No_or_Unk        6472  10251
# 1    Apr          Yes        7106   3586
# 2    Aug    No_or_Unk        7694   3365
# 3    Aug          Yes        7573    334
# 4    Jul    No_or_Unk        6978   3780
# 5    Jul          Yes        8558    520
# 6    Jun    No_or_Unk        7025   2746
# 7    Jun          Yes        6307    559
# 8    Mar    No_or_Unk        2965   1780
# 9    Mar          Yes        3315    532
# 10   May    No_or_Unk        8913   5922
# 11   May          Yes        7767   1410
# 12   Nov    No_or_Unk        4569  12744
# 13   Nov          Yes        4414    444
# 14   Oct    No_or_Unk        7185   7375
# 15   Oct          Yes        7447    580
# 16   Sep    No_or_Unk        7726   2877
# 17   Sep          Yes        5841    192

# %%
# Set and reorder months
new_hosp_date['month'] = pd.Categorical(new_hosp_date['month'], categories=months_order, ordered=True)

# %%
hosp_date_plot = sns.catplot(x = "month", y = "count", hue = "hospitalized", data=new_hosp_date, kind = "bar", height=6)
hosp_date_plot.fig.suptitle('Hospitalizations by Month')
plt.show()

# %% [markdown]
# ## Deaths by Date

# %%
deaths_date
# Out:
#     cartodb_id the_geom the_geom_webmercator clinical_date_of_death  \
# 0            1     None                 None   2020-06-16T00:00:00Z
# 1            2     None                 None   2020-05-25T00:00:00Z
# 2            3     None                 None   2020-06-09T00:00:00Z
# 3            4     None                 None   2020-05-03T00:00:00Z
# 4            5     None                 None   2020-06-13T00:00:00Z
# ..         ...      ...                  ...                    ...
# 74          75     None                 None   2020-05-20T00:00:00Z
# 75          76     None                 None   2020-05-21T00:00:00Z
# 76          77     None                 None   2020-04-08T00:00:00Z
# 77          78     None                 None   2020-05-24T00:00:00Z
# 78          79     None                 None   2020-04-26T00:00:00Z
#
#    covid_outcome  count         etl_timestamp
# 0           DIED      6  2020-11-20T18:20:02Z
# 1           DIED     13  2020-11-20T18:20:02Z
# 2           DIED      6  2020-11-20T18:20:02Z
# 3           DIED     25  2020-11-20T18:20:02Z
# 4           DIED      7  2020-11-20T18:20:02Z
# ..           ...    ...                   ...
# 74          DIED     14  2020-11-20T18:20:02Z
# 75          DIED     10  2020-11-20T18:20:02Z
# 76          DIED     26  2020-11-20T18:20:02Z
# 77          DIED      8  2020-11-20T18:20:02Z
# 78          DIED     21  2020-11-20T18:20:02Z
#
# [79 rows x 7 columns]

# %%
deaths_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   cartodb_id              79 non-null     int64
#  1   the_geom                0 non-null      object
#  2   the_geom_webmercator    0 non-null      object
#  3   clinical_date_of_death  78 non-null     object
#  4   covid_outcome           79 non-null     object
#  5   count                   79 non-null     int64
#  6   etl_timestamp           79 non-null     object
# dtypes: int64(2), object(5)
# memory usage: 4.4+ KB

# %%
# It appears that this data starts April 1st, 2020. Given that there is an NaN in the data, 
# I'm going to assume that those deaths are from March; I will fill this NaN with '2020-03-31'.
deaths_date['clinical_date_of_death'].fillna('2020-03-31', inplace=True)

# %%
# Remove 'T00:00:00Z' from 'clinical_date_of_death'
deaths_date['clinical_date_of_death'] =  [re.sub('T(.*?)Z','', str(x)) for x in deaths_date['clinical_date_of_death']]

# %%
# Add months to the data set and group by month to get a month by month analysis.
months = []
for i in deaths_date['clinical_date_of_death']:
    months.append(datetime.datetime.strptime(i, "%Y-%m-%d").month)

month_names = []
for i in months:
    month_names.append(calendar.month_abbr[i])

deaths_date['month'] = month_names

month_df = deaths_date.groupby('month', as_index=False).sum()
month_df
# Out:
#   month  cartodb_id  count
# 0   Apr        1259    925
# 1   Aug          40      6
# 2   Jul          36      6
# 3   Jun         589    125
# 4   Mar          21     14
# 5   May        1170    530
# 6   Nov          45      8

# %%
# Set and reorder months
months_order = ['Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Nov']
month_df['month'] = pd.Categorical(month_df['month'], categories=months_order, ordered=True)

# %%
plt.figure(figsize=(10,6))
plt.title('Deaths by Month')
date_plot = sns.barplot(x='month', y='count', data=month_df)
plt.show()

# %%
print('Age data total deaths =', deaths_age['count'].sum())
print('Race data total deaths =', deaths_race['count'].sum())
print('Date data total deaths =', deaths_date['count'].sum())
# Out:
# Age data total deaths = 1945
# Race data total deaths = 1949
# Date data total deaths = 1614

# %% [markdown]
# Some discrepencies in the total death counts. Perhaps related to data collection issues?
